# %%
from sklearn.datasets import make_classification

X, y = make_classification()

X
# Out:
# array([[-1.67569347, -1.60533089, -0.21224224, ..., -0.51098746,
#         -0.70017085, -1.46454239],
#        [ 0.75231066, -1.34584865, -0.69215458, ..., -0.53367753,
#          1.05736696, -2.03084091],
#        [-0.73972674,  0.75360152, -0.28770191, ...,  2.13223749,
#          0.55169211, -1.67542418],
#        ...,
#        [-1.90489994,  0.60429214,  1.00529287, ...,  0.19922151,
#          1.14183168, -0.73386961],
#        [ 2.2890664 , -0.37234015,  0.54546893, ...,  1.01602567,
#          0.36278133,  0.15227058],
#        [ 0.85294443,  1.29073649,  2.23640368, ..., -1.16633744,
#         -1.07663846, -0.05517818]])

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier().fit(X, y)

tree.plot_tree(clf,proportion='true')
# Out:
# [Text(0.5, 0.9166666666666666, 'x[19] <= 0.582\ngini = 0.5\nsamples = 100.0%\nvalue = [0.5, 0.5]'),
#  Text(0.375, 0.75, 'x[19] <= -0.43\ngini = 0.238\nsamples = 58.0%\nvalue = [0.862, 0.138]'),
#  Text(0.25, 0.5833333333333334, 'gini = 0.0\nsamples = 40.0%\nvalue = [1.0, 0.0]'),
#  Text(0.5, 0.5833333333333334, 'x[3] <= 0.075\ngini = 0.494\nsamples = 18.0%\nvalue = [0.556, 0.444]'),
#  Text(0.25, 0.4166666666666667, 'x[7] <= 0.347\ngini = 0.42\nsamples = 10.0%\nvalue = [0.3, 0.7]'),
#  Text(0.125, 0.25, 'gini = 0.0\nsamples = 2.0%\nvalue = [1.0, 0.0]'),
#  Text(0.375, 0.25, 'x[19] <= 0.343\ngini = 0.219\nsamples = 8.0%\nvalue = [0.125, 0.875]'),
#  Text(0.25, 0.08333333333333333, 'gini = 0.0\nsamples = 7.0%\nvalue = [0.0, 1.0]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1.0%\nvalue = [1.0, 0.0]'),
#  Text(0.75, 0.4166666666666667, 'x[18] <= -1.578\ngini = 0.219\nsamples = 8.0%\nvalue = [0.875, 0.125]'),
#  Text(0.625, 0.25, 'gini = 0.0\nsamples = 1.0%\nvalue = [0.0, 1.0]'),
#  Text(0.875, 0.25, 'gini = 0.0\nsamples = 7.0%\nvalue = [1.0, 0.0]'),
#  Text(0.625, 0.75, 'gini = 0.0\nsamples = 42.0%\nvalue = [0.0, 1.0]')]

# %%
import sklearn.metrics as metrics

metrics.accuracy_score(y,clf.predict(X))
# Out:
# 1.0

# %%
import pandas as pd

df = pd.read_csv("../datasets/dataset_tennis.csv")
df
# Out:
#      outlook temperature humidity    wind tennis
# 0      sunny         hot     high    weak     no
# 1      sunny         hot     high  strong     no
# 2   overcast         hot     high    weak    yes
# 3       rain        mild     high    weak    yes
# 4       rain        cool   normal    weak    yes
# 5       rain        cool   normal  strong     no
# 6   overcast        cool   normal  strong    yes
# 7      sunny        mild     high    weak     no
# 8      sunny        cool   normal    weak    yes
# 9       rain        mild   normal    weak    yes
# 10     sunny        mild   normal  strong    yes
# 11  overcast        mild     high  strong    yes
# 12  overcast         hot   normal    weak    yes
# 13      rain        mild     high  strong     no

# %%
X = df.iloc[:, 0:-1].values
y = df.iloc[:, 4].values

clf = tree.DecisionTreeClassifier().fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 X = df.iloc[:, 0:-1].values
#       2 y = df.iloc[:, 4].values
# ----> 4 clf = tree.DecisionTreeClassifier().fit(X, y)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/tree/_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/tree/_classes.py:186, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     184 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186 X, y = self._validate_data(
#     187     X, y, validate_separately=(check_X_params, check_y_params)
#     188 )
#     189 if issparse(X):
#     190     X.sort_indices()
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:549, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     547 if "estimator" not in check_X_params:
#     548     check_X_params = {**default_check_params, **check_X_params}
# --> 549 X = check_array(X, input_name="X", **check_X_params)
#     550 if "estimator" not in check_y_params:
#     551     check_y_params = {**default_check_params, **check_y_params}
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:877, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     875         array = xp.astype(array, dtype, copy=False)
#     876     else:
# --> 877         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     878 except ComplexWarning as complex_warning:
#     879     raise ValueError(
#     880         "Complex data not supported\n{}\n".format(array)
#     881     ) from complex_warning
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# ValueError: could not convert string to float: 'sunny'

# %%
from sklearn import preprocessing

X_enc = preprocessing.OrdinalEncoder().fit_transform(X)
X_enc
# Out:
# array([[2., 1., 0., 1.],
#        [2., 1., 0., 0.],
#        [0., 1., 0., 1.],
#        [1., 2., 0., 1.],
#        [1., 0., 1., 1.],
#        [1., 0., 1., 0.],
#        [0., 0., 1., 0.],
#        [2., 2., 0., 1.],
#        [2., 0., 1., 1.],
#        [1., 2., 1., 1.],
#        [2., 2., 1., 0.],
#        [0., 2., 0., 0.],
#        [0., 1., 1., 1.],
#        [1., 2., 0., 0.]])

# %%
clf = tree.DecisionTreeClassifier().fit(X_enc, y)

tree.plot_tree(clf,proportion='true')
# Out:
# [Text(0.4444444444444444, 0.9, 'x[0] <= 0.5\ngini = 0.459\nsamples = 100.0%\nvalue = [0.357, 0.643]'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 28.6%\nvalue = [0.0, 1.0]'),
#  Text(0.5555555555555556, 0.7, 'x[2] <= 0.5\ngini = 0.5\nsamples = 71.4%\nvalue = [0.5, 0.5]'),
#  Text(0.3333333333333333, 0.5, 'x[0] <= 1.5\ngini = 0.32\nsamples = 35.7%\nvalue = [0.8, 0.2]'),
#  Text(0.2222222222222222, 0.3, 'x[3] <= 0.5\ngini = 0.5\nsamples = 14.3%\nvalue = [0.5, 0.5]'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [1.0, 0.0]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [0.0, 1.0]'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.0\nsamples = 21.4%\nvalue = [1.0, 0.0]'),
#  Text(0.7777777777777778, 0.5, 'x[3] <= 0.5\ngini = 0.32\nsamples = 35.7%\nvalue = [0.2, 0.8]'),
#  Text(0.6666666666666666, 0.3, 'x[0] <= 1.5\ngini = 0.5\nsamples = 14.3%\nvalue = [0.5, 0.5]'),
#  Text(0.5555555555555556, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [1.0, 0.0]'),
#  Text(0.7777777777777778, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [0.0, 1.0]'),
#  Text(0.8888888888888888, 0.3, 'gini = 0.0\nsamples = 21.4%\nvalue = [0.0, 1.0]')]
